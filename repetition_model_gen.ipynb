# %%
import pandas as pd
import re
# Open a file: file
sent_table = pd.read_csv('data/corpus.txt', delimiter='|', usecols=['text'])
#print(sent_table)


for i in sent_table.index.values:
    #print(sent_table.iloc[i]['text']);
    #sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace('''O ''', '''Oh''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace('''`''', ''' \'''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace(''' ` ''', '''\'''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace(''' `''', '''\'''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace(''' \'''','''\'''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace('''\'d''','''ed''')
    #sent_table.iloc[i]['text'] = re.sub(r'''[^\w\d'\-\s]+''','',sent_table.iloc[i]['text']);
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].strip();
    
    
#%%
def uniq(input):
  output = []
  for x in input:
    if x not in output:
      output.append(x)
  return output

def recursive_len(item):
    if type(item) == list:
        return sum(recursive_len(subitem) for subitem in item)
    else:
        return 1

# %%
import pprint
import nltk
import numpy as np
import time
from datetime import datetime
from enum import Enum 
import json
num_figs=10
max_fig_length=18
base_path = 'data/rhet/repitition/'
base_path_output = 'data/rhet/output/'
corpus = 'sonnets'

fig_names = ["Anadiplosis", "Anaphora", "Antimetabole", "Conduplicatio", "Epanalepsis", "Epistrophe", "Epizeuxis", "Ploce", "Polysyndeton", "Symploce"]

class RHETORICAL_FIGURES(Enum):
    ANADIPLOSIS = 0
    ANAPHORA = 1
    ANTIMETABOLE = 2
    CONDUPLICATIO = 3
    EPANALEPSIS = 4
    EPISTROPHE = 5
    EPIZEUXIS = 6
    PLOCE = 7
    POLYSYNDETON = 8
    SYMPLOCE = 9
    
#FIGURE_DESCRIPTION[RHETORICAL_FIGURES['ANADIPLOSIS'].name].value
class FIGURE_DESCRIPTION(Enum):
    ANADIPLOSIS = 'Repetition of the ending word or phrase from the previous clause at the beginning of the next.'
    ANAPHORA = 'Repetition of a word or phrase at the beginning of successive phrases or clauses.'
    ANTIMETABOLE = 'Repetition of words in reverse grammatical order.'
    CONDUPLICATIO = 'The repetition of a word or phrase.'
    EPANALEPSIS = 'Repetition at the end of a clause of the word or phrase that began it.'
    EPISTROPHE = 'Repetition of the same word or phrase at the end of successive clauses.'
    EPIZEUXIS = 'Repetition of a word or phrase with no others between.'
    PLOCE = 'The repetition of word in a short span of text for rhetorical emphasis.'
    POLYSYNDETON = '"Excessive" repetition of conjunctions between clauses.'
    SYMPLOCE = 'Repetition of a word or phrase at the beginning, and of another at the end, of successive clauses.'

class FigureInfo:

    def __init__(self, unique_id, orig_text, pos_template, repitition_template):
        self.unique_id = unique_id
        self.orig_text = orig_text
        self.pos_template = pos_template
        self.repitition_template = repitition_template
    
    def set_props(self, num_lines,num_tokens,num_rep_groups,num_tot_reps,fig_type):
        self.num_lines = num_lines
        self.num_tokens = num_tokens
        self.num_rep_groups = num_rep_groups
        self.num_tot_reps = num_tot_reps
        self.fig_type = fig_type
    
    def set_orig_rep_words(self, orig_rep_words):
        self.orig_rep_words = orig_rep_words
    
    def get_orig_rep_words(self):
        return self.orig_rep_words
    
    def get_unique_id(self):
        return self.unique_id
    
    def get_orig_text(self):
        return self.orig_text
    
    def get_pos_template(self):
        return self.pos_template
    
    def get_repitition_template(self):
        return self.repitition_template
    
    def get_num_lines(self):
        return self.num_lines
    
    def get_num_tokens(self):
        return self.num_tokens
    
    def get_num_rep_groups(self):
        return self.num_rep_groups
    
    def get_num_tot_reps(self):
        return self.num_tot_reps
    
    def get_fig_type(self):
        return self.fig_type
    
    def get_fig_desc(self):
        return FIGURE_DESCRIPTION[self.get_fig_type()].value
    
    def to_string(self):
        pp = pprint.PrettyPrinter(indent=4, width=160)
        return pprint.pformat(self.__dict__) + "\n"
    
    def print(self):
        pp = pprint.PrettyPrinter(indent=4, width=160)
        pp.pprint(self.__dict__)
        print("\n")

    
    
    
fig_descs = \
    [
        "Repetition of the ending word or phrase from the previous clause at the beginning of the next.",
        "Repetition of a word or phrase at the beginning of successive phrases or clauses.",
        "Repetition of words in reverse grammatical order.",
        "The repetition of a word or phrase.",
        "Repetition at the end of a clause of the word or phrase that began it.",
        "Repetition of the same word or phrase at the end of successive clauses.",
        "Repetition of a word or phrase with no others between.",
        "The repetition of word in a short span of text for rhetorical emphasis.",
        "\"Excessive\" repetition of conjunctions between clauses.",
        "Repetition of a word or phrase at the beginning, and of another at the end, of successive clauses."
    ]

rep_figs = ["sonnet_anadiplosis.csv", "sonnet_anaphora.csv", "sonnet_antimetabole.csv",
"sonnet_conduplicatio.csv", 
            "sonnet_epanalepsis.csv", "sonnet_epistrophe.csv", "sonnet_epizeuxis.csv",
"sonnet_ploce.csv", 
            "sonnet_polysyndeton.csv", "sonnet_symploce.csv"]
unique_id = 0
fig_dict = dict()
for nfig in range(0,num_figs):
    cur_fig_name = fig_names[nfig]
    cur_fig_desc = fig_descs[nfig]
    cur_fig_rhet_file = rep_figs[nfig]

    rhet_table = pd.read_csv(base_path+cur_fig_rhet_file)
    #print(rhet_table)
    fig_ids = rhet_table.figure_id.unique()
    #print(fig_ids)
    for id in fig_ids:
       figure = rhet_table.loc[rhet_table['figure_id'] == id]
       rep_word = []
       sentence_ids = figure['sentence_id'].values
       sentence_ids = uniq(sentence_ids)
       if(not sorted(sentence_ids) == list(range(min(sentence_ids), max(sentence_ids)+1))): continue 

       fig_words = uniq([x.lower().replace('''\'d''', '''ed''') for x in list(figure['word'].values)])
       fig_words_dict = dict([[fig_words[y-1], y] for y in range(1, len(fig_words)+1)])
       #print(fig_words_dict)
        
       orig_text = [ nltk.word_tokenize(sent_table.iloc[i]['text']) for i in sentence_ids]
       
       #for l in range(0,len(roman)):
           #del orig_text[roman[l][0]][roman[l][1]]
    
       orig_text = [[orig_text[i][j].lower() for j in range(0,len(orig_text[i]))] for i in range(0,len(orig_text))]
       if(recursive_len(orig_text) > 1):
           tagged = [nltk.pos_tag(orig_text[i]) for i in  range(0,len(orig_text))]
           #print(orig_text)
           pos_templates = [[tagged[i][j][1] for j in range(0,len(tagged[i]))] for i in range(0,len(tagged))]
           #print(pos_templates)
           
           assert(np.shape(orig_text) == np.shape(pos_templates))
           fig_words_count_dict = dict([[fig_words[y], 0] for y in range(0, len(fig_words))])
        
           rep_templates = [['0' for j in range(0,len(orig_text[i]))] for i in range(0,len(orig_text))]
           for j in range(0,len(orig_text)):
               for k in range(0,len(orig_text[j])):
                   wordc = orig_text[j][k]
                   for word_rep in list(fig_words_dict.keys()):
                       if(word_rep in wordc):
                           fig_words_count_dict[word_rep] = fig_words_count_dict[word_rep]+1
                           rep_templates[j][k] = str(fig_words_dict[word_rep]) + str(fig_words_count_dict[word_rep])
           
           unique_id = unique_id+1
           #print("unique_id: " + str(unique_id))
           #print("num_lines: " + str(len(sentence_ids)))
           #print("num_tokens: " + str(recursive_len(orig_text)))
           #print("num_rep_groups: " + str(len(fig_words_dict.keys())))
           #print("num_tot_reps: " + str(sum(fig_words_count_dict.values())))
           #print("fig_type: " + str(RHETORICAL_FIGURES[cur_fig_name.upper()].name)+ "\n")
           #print("Orig. Text:\n")
           orig_line = ", ".join([' '.join(orig_text[i]) for i in range(0,len(orig_text))])
           fig_info = FigureInfo(unique_id, [[sent_table.iloc[i]['text']] for i in sentence_ids], pos_templates, rep_templates)
           fig_info.set_props(len(sentence_ids), recursive_len(orig_text), len(fig_words_dict.keys()), sum(fig_words_count_dict.values()), RHETORICAL_FIGURES[cur_fig_name.upper()].name)
           fig_info.set_orig_rep_words([k  for  k in fig_words_dict.keys()])
           fig_dict[unique_id] = fig_info
           #print(orig_text)
           #print(rep_templates)
           #print(pos_templates)
           #print("Rep. Words:\n")
           #print(fig_words_dict)
           #print("Rep. Words Count:\n")
           #print(fig_words_count_dict)
           #print("POS Template:\n")
           #print(pos_templates)
           #print("Rep Template:\n")
           #print(rep_templates)
           
  
   #for index, row in figure.iterrows():
    
#print(fig_dict.values)

# %%
from py_files.Limericks import Limerick_Generate
from datetime import datetime
lg = Limerick_Generate(model_dir='/gpt2/models/345M',model_name='345M')
n=100
num_figs=10
max_fig_length=18
base_path = '/home/dineshp/Poetix18/data/rhet/repitition/'
base_path_output = '/home/dineshp/Poetix18/data/rhet/output/'
corpus = 'sonnets'
    
single_line = {k: v for k, v in fig_dict.items() if v.get_num_lines() == 1 }

timestamp = int(time.mktime(datetime.now().timetuple()))
out_name = base_path_output + corpus + "_" + str(timestamp) + ".txt"
f = open(out_name,"w+")

fig_and_desc = [e.name + ": " + d.value for e,d in zip(RHETORICAL_FIGURES,FIGURE_DESCRIPTION)]
fig_and_desc.insert(0, "FIGURE: Description\n")
for fd in fig_and_desc:
    f.write(fd)

for k, v in single_line.items():
    prompt = lg.enc.encode(' '.join(v.get_orig_text()[0]))
    rep_template = v.get_repitition_template()[0]
    pos_template = v.get_pos_template()[0]
    banned_set = v.get_orig_rep_words()
    
    try:
        f.write(v.to_string())
        new_sentences = lg.gen_line_gpt_cc(cctemplate=rep_template, w=None, encodes=prompt, default_template=pos_template, banned_set=banned_set,search_space=n)
        sents = [new_sentences[j][0] for j in range(len(new_sentences))]
        sent_done = [' '.join(sents[j]) for j in range(len(new_sentences))]
        f.write(" \n".join(sent_done))
        f.flush()
        print(" \n".join(sent_done))

    except Exception:
        print(Exception)
        pass
    f.write("\n-----------------------------------------------------------------------------------------------------------------------------------------------------\n")
# Out:
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# []
# []
# <class 'Exception'>
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9eeef9ac6296> in <module>
#      28     try:
#      29         f.write(v.to_string())
# ---> 30         new_sentences = lg.gen_line_gpt_cc(cctemplate=rep_template, w=None, encodes=prompt, default_template=pos_template, banned_set=banned_set,search_space=n)
#      31         sents = [new_sentences[j][0] for j in range(len(new_sentences))]
#      32         sent_done = [' '.join(sents[j]) for j in range(len(new_sentences))]
#
# ~/Poetix18/py_files/Limericks.py in gen_line_gpt_cc(self, cctemplate, w, encodes, default_template, rhyme_word, rhyme_set, banned_set, search_space)
#     993                     if (CC_MET):
#     994                         # Restrict the word to have the POS of the template
# --> 995                         if POS in self.words_to_pos[word]:
#     996                             # Enforce rhyme if last word
#     997                             if i == len(template) - 1 and rhyme_set and (word.lower().strip() not in rhyme_set):
#
# KeyboardInterrupt:

# %%
    
single_line = {k: v for k, v in fig_dict.items() if v.get_num_lines() == 1 }

for k, v in single_line.items():
    
        v.print()
# Out:
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['one'],
#     'orig_text': [['Who , all in one , one pleasing note do sing :']],
#     'pos_template': [['WP', ',', 'DT', 'IN', 'CD', ',', 'CD', 'NN', 'NN', 'VBP', 'NN', ':']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 1}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['him'],
#     'orig_text': [['Featured like him , like him with friends possessed ,']],
#     'pos_template': [['VBN', 'IN', 'PRP', ',', 'IN', 'PRP', 'IN', 'NNS', 'VBN', ',']],
#     'repitition_template': [['0', '0', '11', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 2}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['love'],
#     'orig_text': [["And there reigns Love , and all Love's loving parts ,"]],
#     'pos_template': [['CC', 'EX', 'NNS', 'NN', ',', 'CC', 'DT', 'VBP', 'POS', 'NN', 'NNS', ',']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 3}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['mine'],
#     'orig_text': [['As thou being mine , mine is thy good report .']],
#     'pos_template': [['IN', 'NN', 'VBG', 'NN', ',', 'NN', 'VBZ', 'JJ', 'JJ', 'NN', '.']],
#     'repitition_template': [['0', '0', '0', '11', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 4}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['best'],
#     'orig_text': [['Look what is best , that best I wish in thee :']],
#     'pos_template': [['VB', 'WP', 'VBZ', 'RBS', ',', 'IN', 'JJS', 'NN', 'NN', 'IN', 'NN', ':']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 5}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['love'],
#     'orig_text': [['But love , for love , thus shall excuse my jade , --']],
#     'pos_template': [['CC', 'NN', ',', 'IN', 'NN', ',', 'RB', 'MD', 'VB', 'PRP$', 'NN', ',', ':']],
#     'repitition_template': [['0', '11', '0', '0', '12', '0', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 6}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 3,
#     'orig_rep_words': ['one'],
#     'orig_text': [['Since every one , hath every one , one shade ,']],
#     'pos_template': [['IN', 'DT', 'CD', ',', 'NN', 'DT', 'CD', ',', 'CD', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '12', '0', '13', '0', '0']],
#     'unique_id': 7}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['none'],
#     'orig_text': [['But you like none , none you , for constant heart .']],
#     'pos_template': [['CC', 'PRP', 'IN', 'NN', ',', 'NN', 'PRP', ',', 'IN', 'JJ', 'NN', '.']],
#     'repitition_template': [['0', '0', '0', '11', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 8}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['loss'],
#     'orig_text': [['Increasing store with loss , and loss with store ;']],
#     'pos_template': [['VBG', 'NN', 'IN', 'NN', ',', 'CC', 'NN', 'IN', 'NN', ':']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '0']],
#     'unique_id': 9}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['mine'],
#     'orig_text': [['As , thou being mine , mine is thy good report .']],
#     'pos_template': [['IN', ',', 'IN', 'VBG', 'NN', ',', 'NN', 'VBZ', 'JJ', 'JJ', 'NN', '.']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 13}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['you'],
#     'orig_text': [['Drawn after you , you pattern of all those .']],
#     'pos_template': [['NN', 'IN', 'PRP', ',', 'PRP', 'VBP', 'IN', 'DT', 'DT', '.']],
#     'repitition_template': [['0', '0', '11', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 14}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['less'],
#     'orig_text': [['I love not less , though less the show appear ;']],
#     'pos_template': [['NNS', 'VBP', 'RB', 'RBR', ',', 'RB', 'JJR', 'DT', 'NN', 'VBP', ':']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 15}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['one'],
#     'orig_text': [['To one , of one , still such , and ever so .']],
#     'pos_template': [['TO', 'CD', ',', 'IN', 'CD', ',', 'RB', 'JJ', ',', 'CC', 'RB', 'RB', '.']],
#     'repitition_template': [['0', '11', '0', '0', '12', '0', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 16}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['hopes'],
#     'orig_text': [['Applying fears to hopes , and hopes to fears ,']],
#     'pos_template': [['VBG', 'NNS', 'TO', 'NNS', ',', 'CC', 'VBZ', 'TO', 'NNS', ',']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '0']],
#     'unique_id': 17}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['you'],
#     'orig_text': [['And soon to you , as you to me , then tendered']],
#     'pos_template': [['CC', 'RB', 'TO', 'PRP', ',', 'IN', 'PRP', 'TO', 'PRP', ',', 'RB', 'VBD']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 18}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['yours'],
#     'orig_text': [['Mine ransoms yours , and yours must ransom me .']],
#     'pos_template': [['NN', 'NNS', 'NNS', ',', 'CC', 'NNS', 'MD', 'VB', 'PRP', '.']],
#     'repitition_template': [['0', '0', '11', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 19}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['music'],
#     'orig_text': [["How oft when thou , my music , music play ' st ,"]],
#     'pos_template': [['WRB', 'JJ', 'WRB', 'NN', ',', 'PRP$', 'NN', ',', 'NN', 'NN', "''", 'NN', ',']],
#     'repitition_template': [['0', '0', '0', '0', '0', '0', '11', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 20}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['action'],
#     'orig_text': [['Is lust in action : and till action , lust']],
#     'pos_template': [['VBZ', 'JJ', 'IN', 'NN', ':', 'CC', 'VB', 'NN', ',', 'NN']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 21}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['love'],
#     'orig_text': [['Make but my name thy love , and love that still ,']],
#     'pos_template': [['NN', 'CC', 'PRP$', 'NN', 'JJ', 'NN', ',', 'CC', 'VB', 'DT', 'RB', ',']],
#     'repitition_template': [['0', '0', '0', '0', '0', '11', '0', '0', '12', '0', '0', '0']],
#     'unique_id': 25}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['words'],
#     'orig_text': [['Lest sorrow lend me words , and words express']],
#     'pos_template': [['JJS', 'NN', 'VB', 'PRP', 'NNS', ',', 'CC', 'NNS', 'NN']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '12', '0']],
#     'unique_id': 26}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['hate'],
#     'orig_text': [["' I hate' , from hate away she threw ,"]],
#     'pos_template': [['POS', 'JJ', 'NN', "''", ',', 'IN', 'NN', 'RB', 'PRP', 'VBD', ',']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 28}
#
#
# {   'fig_type': 'ANADIPLOSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['water'],
#     'orig_text': [["Love's fire heats water , water cools not love ."]],
#     'pos_template': [['NN', 'POS', 'NN', 'VBZ', 'NN', ',', 'NN', 'NNS', 'RB', 'VB', '.']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 31}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thou'],
#     'orig_text': [['Thou mayst call thine when thou from youth convertest ,']],
#     'pos_template': [['JJ', 'NN', 'NN', 'NN', 'WRB', 'NN', 'IN', 'NN', 'NN', ',']],
#     'repitition_template': [['11', '0', '0', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 35}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['to'],
#     'orig_text': [['To change your day of youth to sullied night ,']],
#     'pos_template': [['TO', 'VB', 'PRP$', 'NN', 'IN', 'NN', 'TO', 'VB', 'NN', ',']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '12', '0', '0', '0']],
#     'unique_id': 37}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['they'],
#     'orig_text': [['They draw but what they see , know not the heart .']],
#     'pos_template': [['PRP', 'VBP', 'CC', 'WP', 'PRP', 'VBP', ',', 'VBP', 'RB', 'DT', 'NN', '.']],
#     'repitition_template': [['11', '0', '0', '0', '12', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 42}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 6,
#     'orig_rep_words': ['i'],
#     'orig_text': [['Their images I loved , I view in thee ,']],
#     'pos_template': [['PRP$', 'NNS', 'VBP', 'VBN', ',', 'JJ', 'NN', 'IN', 'NN', ',']],
#     'repitition_template': [['11', '12', '13', '0', '0', '14', '15', '16', '0', '0']],
#     'unique_id': 47}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 5,
#     'orig_rep_words': ['thou', 'art'],
#     'orig_text': [['Save where thou art not , though I feel thou art ,']],
#     'pos_template': [['VB', 'WRB', 'JJ', 'NN', 'RB', ',', 'IN', 'JJ', 'VBP', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '21', '0', '0', '12', '0', '0', '13', '22', '0']],
#     'unique_id': 55}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['being'],
#     'orig_text': [['Being had , to triumph ; being lacked , to hope .']],
#     'pos_template': [['VBG', 'VBD', ',', 'TO', 'VB', ':', 'VBG', 'VBN', ',', 'TO', 'VB', '.']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 57}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['to'],
#     'orig_text': [['Being had , to triumph ; being lacked , to hope .']],
#     'pos_template': [['VBG', 'VBD', ',', 'TO', 'VB', ':', 'VBG', 'VBN', ',', 'TO', 'VB', '.']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 58}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 14,
#     'num_tot_reps': 5,
#     'orig_rep_words': ['r'],
#     'orig_text': [["Wh' r we are mended , or wh' r better they ,"]],
#     'pos_template': [['NN', "''", 'NN', 'PRP', 'VBP', 'VBN', ',', 'CC', 'NN', "''", 'NN', 'RBR', 'PRP', ',']],
#     'repitition_template': [['0', '0', '11', '0', '12', '0', '0', '13', '0', '0', '14', '15', '0', '0']],
#     'unique_id': 62}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['to'],
#     'orig_text': [['But weep to have , that which it fears to lose .']],
#     'pos_template': [['CC', 'NN', 'TO', 'VB', ',', 'IN', 'WDT', 'PRP', 'VBZ', 'TO', 'VB', '.']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 66}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['my'],
#     'orig_text': [['My name be buried where my body is ,']],
#     'pos_template': [['PRP$', 'NN', 'VB', 'VBN', 'WRB', 'PRP$', 'NN', 'VBZ', ',']],
#     'repitition_template': [['11', '0', '0', '0', '0', '12', '0', '0', '0']],
#     'unique_id': 69}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 8,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thou'],
#     'orig_text': [['When thou reviewest this , thou dost review']],
#     'pos_template': [['WRB', 'NN', 'NN', 'DT', ',', 'VBZ', 'NN', 'NN']],
#     'repitition_template': [['0', '11', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 70}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['i'],
#     'orig_text': [['O ! how I faint when I of you do write ,']],
#     'pos_template': [['NN', '.', 'WRB', 'JJ', 'NN', 'WRB', 'NN', 'IN', 'PRP', 'VBP', 'VB', ',']],
#     'repitition_template': [['0', '0', '0', '11', '12', '0', '13', '0', '0', '0', '14', '0']],
#     'unique_id': 75}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 5,
#     'orig_rep_words': ['i', 'found'],
#     'orig_text': [['I found , or thought I found , you did exceed']],
#     'pos_template': [['NN', 'VBD', ',', 'CC', 'VBD', 'NN', 'VBD', ',', 'PRP', 'VBD', 'VB']],
#     'repitition_template': [['11', '21', '0', '0', '0', '12', '22', '0', '0', '13', '0']],
#     'unique_id': 76}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 15,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['tis'],
#     'orig_text': [["Hearing you praised , I say'' tis so , ' tis true ,'"]],
#     'pos_template': [['VBG', 'PRP', 'VBN', ',', 'NNS', 'VBP', "''", 'NN', 'RB', ',', "''", 'NN', 'JJ', ',', "''"]],
#     'repitition_template': [['0', '0', '0', '0', '0', '0', '0', '11', '0', '0', '0', '12', '0', '0', '0']],
#     'unique_id': 79}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 14,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thy'],
#     'orig_text': [["Thy self thou gav ' st , thy own worth then not knowing ,"]],
#     'pos_template': [['JJ', 'NN', 'NN', 'NN', "''", 'NN', ',', 'JJ', 'JJ', 'NN', 'RB', 'RB', 'VBG', ',']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 81}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['happy', 'to'],
#     'orig_text': [['Happy to have thy love , happy to die !']],
#     'pos_template': [['JJ', 'TO', 'VB', 'JJ', 'NN', ',', 'JJ', 'TO', 'VB', '.']],
#     'repitition_template': [['11', '21', '0', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 84}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thy'],
#     'orig_text': [['Thy looks with me , thy heart in other place :']],
#     'pos_template': [['JJ', 'VBZ', 'IN', 'PRP', ',', 'JJ', 'NN', 'IN', 'JJ', 'NN', ':']],
#     'repitition_template': [['11', '0', '0', '0', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 87}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['what'],
#     'orig_text': [['What freezings have I felt , what dark days seen !']],
#     'pos_template': [['WP', 'NNS', 'VBP', 'VBN', 'NNS', ',', 'WP', 'JJ', 'NNS', 'VBN', '.']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 91}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['beauty'],
#     'orig_text': [["Beauty no pencil , beauty's truth to lay ;"]],
#     'pos_template': [['NN', 'DT', 'NN', ',', 'NN', 'POS', 'NN', 'TO', 'VB', ':']],
#     'repitition_template': [['11', '0', '0', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 92}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['to', 'be'],
#     'orig_text': [['And to be praised of ages yet to be .']],
#     'pos_template': [['CC', 'TO', 'VB', 'VBN', 'IN', 'NNS', 'RB', 'TO', 'VB', '.']],
#     'repitition_template': [['0', '11', '21', '0', '0', '0', '0', '12', '22', '0']],
#     'unique_id': 93}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 14,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['tis'],
#     'orig_text': [["O ! ' tis the first , ' tis flattery in my seeing ,"]],
#     'pos_template': [['NN', '.', "''", 'IN', 'DT', 'JJ', ',', "''", 'NN', 'NN', 'IN', 'PRP$', 'NN', ',']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '0', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 103}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['we'],
#     'orig_text': [['We sicken to shun sickness when we purge ;']],
#     'pos_template': [['PRP', 'VBP', 'TO', 'VB', 'NN', 'WRB', 'PRP', 'VBP', ':']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 104}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['i', 'am'],
#     'orig_text': [['No , I am that I am , and they that level']],
#     'pos_template': [['DT', ',', 'VB', 'VBP', 'IN', 'NN', 'VBP', ',', 'CC', 'PRP', 'DT', 'NN']],
#     'repitition_template': [['0', '0', '11', '21', '0', '12', '22', '0', '0', '0', '0', '0']],
#     'unique_id': 105}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thy'],
#     'orig_text': [['Thy gift , thy tables , are within my brain']],
#     'pos_template': [['JJ', 'NN', ',', 'JJ', 'NNS', ',', 'VBP', 'IN', 'PRP$', 'NN']],
#     'repitition_template': [['11', '0', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 106}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['thou', 'art'],
#     'orig_text': [['Thou art as tyrannous , so as thou art ,']],
#     'pos_template': [['JJ', 'NN', 'IN', 'JJ', ',', 'RB', 'IN', 'JJ', 'NN', ',']],
#     'repitition_template': [['11', '21', '0', '0', '0', '0', '0', '12', '22', '0']],
#     'unique_id': 113}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['will'],
#     'orig_text': [["' Will' , will fulfil the treasure of thy love ,"]],
#     'pos_template': [["''", 'MD', "''", ',', 'MD', 'VB', 'DT', 'NN', 'IN', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '11', '0', '0', '12', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 118}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 6,
#     'orig_rep_words': ['i', 'should'],
#     'orig_text': [['For , if I should despair , I should grow mad ,']],
#     'pos_template': [['IN', ',', 'IN', 'NN', 'MD', 'VB', ',', 'NN', 'MD', 'VB', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '12', '21', '13', '0', '14', '22', '0', '0', '0']],
#     'unique_id': 119}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 9,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['my', 'five'],
#     'orig_text': [['But my five wits nor my five senses can']],
#     'pos_template': [['CC', 'PRP$', 'CD', 'NNS', 'CC', 'PRP$', 'CD', 'NNS', 'MD']],
#     'repitition_template': [['0', '11', '21', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 120}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['thou', 'dost'],
#     'orig_text': [['If thou dost seek to have what thou dost hide ,']],
#     'pos_template': [['IN', 'JJ', 'NN', 'NN', 'TO', 'VB', 'WP', 'VBZ', 'NN', 'NN', ',']],
#     'repitition_template': [['0', '11', '21', '0', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 121}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['will'],
#     'orig_text': [["So will I pray that thou mayst have thy ' Will ,'"]],
#     'pos_template': [['RB', 'MD', 'VB', 'NN', 'IN', 'JJ', 'NNS', 'VBP', 'VBN', "''", 'MD', ',', "''"]],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 122}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thee'],
#     'orig_text': [['For I have sworn thee fair , and thought thee bright ,']],
#     'pos_template': [['IN', 'NN', 'VBP', 'VBN', 'JJ', 'NN', ',', 'CC', 'VBD', 'NNS', 'JJ', ',']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 123}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 14,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['how', 'can'],
#     'orig_text': [["How can it ? O ! how can Love's eye be true ,"]],
#     'pos_template': [['WRB', 'MD', 'PRP', '.', 'RB', '.', 'WRB', 'MD', 'VB', 'POS', 'NN', 'VB', 'JJ', ',']],
#     'repitition_template': [['11', '21', '0', '0', '0', '0', '12', '22', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 124}
#
#
# {   'fig_type': 'ANAPHORA',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 3,
#     'orig_rep_words': ['thy'],
#     'orig_text': [['Oaths of thy love , thy truth , thy constancy ;']],
#     'pos_template': [['NNS', 'IN', 'JJ', 'NN', ',', 'JJ', 'NN', ',', 'JJ', 'NN', ':']],
#     'repitition_template': [['0', '0', '11', '0', '0', '12', '0', '0', '13', '0', '0']],
#     'unique_id': 132}
#
#
# {   'fig_type': 'ANTIMETABOLE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['music', 'hear'],
#     'orig_text': [["Music to hear , why hear ' st thou music sadly ?"]],
#     'pos_template': [['NN', 'TO', 'VB', ',', 'WRB', 'VBP', 'POS', 'JJ', 'NN', 'NN', 'RB', '.']],
#     'repitition_template': [['11', '0', '21', '0', '0', '22', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 136}
#
#
# {   'fig_type': 'ANTIMETABOLE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['day', 'night'],
#     'orig_text': [['But day by night and night by day oppressed ,']],
#     'pos_template': [['CC', 'NN', 'IN', 'NN', 'CC', 'NN', 'IN', 'NN', 'VBN', ',']],
#     'repitition_template': [['0', '11', '0', '21', '0', '22', '0', '12', '0', '0']],
#     'unique_id': 141}
#
#
# {   'fig_type': 'ANTIMETABOLE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['store', 'loss'],
#     'orig_text': [['Increasing store with loss , and loss with store ;']],
#     'pos_template': [['VBG', 'NN', 'IN', 'NN', ',', 'CC', 'NN', 'IN', 'NN', ':']],
#     'repitition_template': [['0', '11', '0', '21', '0', '0', '22', '0', '12', '0']],
#     'unique_id': 145}
#
#
# {   'fig_type': 'ANTIMETABOLE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['fears', 'hopes'],
#     'orig_text': [['Applying fears to hopes , and hopes to fears ,']],
#     'pos_template': [['VBG', 'NNS', 'TO', 'NNS', ',', 'CC', 'VBZ', 'TO', 'NNS', ',']],
#     'repitition_template': [['0', '11', '0', '21', '0', '0', '22', '0', '12', '0']],
#     'unique_id': 149}
#
#
# {   'fig_type': 'ANTIMETABOLE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['lust', 'action'],
#     'orig_text': [['Is lust in action : and till action , lust']],
#     'pos_template': [['VBZ', 'JJ', 'IN', 'NN', ':', 'CC', 'VB', 'NN', ',', 'NN']],
#     'repitition_template': [['0', '11', '0', '21', '0', '0', '0', '22', '0', '12']],
#     'unique_id': 150}
#
#
# {   'fig_type': 'ANTIMETABOLE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['well', 'knows'],
#     'orig_text': [['All this the world well knows ; yet none knows well']],
#     'pos_template': [['DT', 'DT', 'DT', 'NN', 'NN', 'VBZ', ':', 'RB', 'NN', 'VBZ', 'RB']],
#     'repitition_template': [['0', '0', '0', '0', '11', '21', '0', '0', '0', '22', '12']],
#     'unique_id': 151}
#
#
# {   'fig_type': 'ANTIMETABOLE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['love', 'water'],
#     'orig_text': [["Love's fire heats water , water cools not love ."]],
#     'pos_template': [['NN', 'POS', 'NN', 'VBZ', 'NN', ',', 'NN', 'NNS', 'RB', 'VB', '.']],
#     'repitition_template': [['11', '0', '0', '0', '21', '0', '22', '0', '0', '12', '0']],
#     'unique_id': 162}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['your', 'sweet'],
#     'orig_text': [['When your sweet issue your sweet form should bear .']],
#     'pos_template': [['WRB', 'PRP$', 'JJ', 'VB', 'PRP$', 'JJ', 'NN', 'MD', 'VB', '.']],
#     'repitition_template': [['0', '11', '21', '0', '12', '22', '0', '0', '0', '0']],
#     'unique_id': 171}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['thy', 'love'],
#     'orig_text': [["Mine be thy love and thy love's use their treasure ."]],
#     'pos_template': [['NN', 'VB', 'JJ', 'NN', 'CC', 'JJ', 'NN', 'POS', 'VBP', 'PRP$', 'NN', '.']],
#     'repitition_template': [['0', '0', '11', '21', '0', '12', '22', '0', '0', '0', '0', '0']],
#     'unique_id': 173}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['man', "'s"],
#     'orig_text': [["Desiring this man's art , and that man's scope ,"]],
#     'pos_template': [['VBG', 'DT', 'NN', 'POS', 'NN', ',', 'CC', 'IN', 'NN', 'POS', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '21', '0', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 178}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 9,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['thy', 'sins'],
#     'orig_text': [['Excusing thy sins more than thy sins are ;']],
#     'pos_template': [['VBG', 'JJ', 'NNS', 'RBR', 'IN', 'JJ', 'NNS', 'VBP', ':']],
#     'repitition_template': [['0', '11', '21', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 179}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 14,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['love', 'her'],
#     'orig_text': [["Thou dost love her , because thou know ' st I love her ;"]],
#     'pos_template': [['NN', 'NN', 'IN', 'PRP', ',', 'IN', 'NN', 'VBP', 'POS', 'NN', 'NN', 'VBP', 'PRP$', ':']],
#     'repitition_template': [['0', '0', '11', '21', '0', '0', '0', '0', '0', '0', '0', '12', '22', '0']],
#     'unique_id': 186}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 5,
#     'orig_rep_words': ['thou', 'art'],
#     'orig_text': [['Save where thou art not , though I feel thou art ,']],
#     'pos_template': [['VB', 'WRB', 'JJ', 'NN', 'RB', ',', 'IN', 'JJ', 'VBP', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '21', '0', '0', '12', '0', '0', '13', '22', '0']],
#     'unique_id': 191}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['that', 'time'],
#     'orig_text': [['Against that time , if ever that time come ,']],
#     'pos_template': [['IN', 'DT', 'NN', ',', 'IN', 'RB', 'IN', 'NN', 'VBN', ',']],
#     'repitition_template': [['0', '11', '21', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 192}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 5,
#     'orig_rep_words': ['every', 'one'],
#     'orig_text': [['Since every one , hath every one , one shade ,']],
#     'pos_template': [['IN', 'DT', 'CD', ',', 'NN', 'DT', 'CD', ',', 'CD', 'NN', ',']],
#     'repitition_template': [['0', '11', '21', '0', '0', '12', '22', '0', '23', '0', '0']],
#     'unique_id': 193}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 14,
#     'num_tot_reps': 7,
#     'orig_rep_words': ['wh', 'r'],
#     'orig_text': [["Wh' r we are mended , or wh' r better they ,"]],
#     'pos_template': [['NN', "''", 'NN', 'PRP', 'VBP', 'VBN', ',', 'CC', 'NN', "''", 'NN', 'RBR', 'PRP', ',']],
#     'repitition_template': [['11', '0', '21', '0', '22', '0', '0', '23', '12', '0', '24', '25', '0', '0']],
#     'unique_id': 194}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['time', "'s"],
#     'orig_text': [["Shall Time's best jewel from Time's chest lie hid ?"]],
#     'pos_template': [['MD', 'NN', 'POS', 'JJS', 'NN', 'IN', 'NN', 'POS', 'JJS', 'NN', 'NN', '.']],
#     'repitition_template': [['0', '11', '21', '0', '0', '0', '12', '22', '0', '0', '0', '0']],
#     'unique_id': 196}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['thy', 'praise'],
#     'orig_text': [['Yet this thy praise can not be so thy praise ,']],
#     'pos_template': [['RB', 'DT', 'JJ', 'NN', 'MD', 'RB', 'VB', 'RB', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '21', '0', '0', '0', '0', '12', '22', '0']],
#     'unique_id': 198}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 5,
#     'orig_rep_words': ['i', 'found'],
#     'orig_text': [['I found , or thought I found , you did exceed']],
#     'pos_template': [['NN', 'VBD', ',', 'CC', 'VBD', 'NN', 'VBD', ',', 'PRP', 'VBD', 'VB']],
#     'repitition_template': [['11', '21', '0', '0', '0', '12', '22', '0', '0', '13', '0']],
#     'unique_id': 200}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['leave', 'me'],
#     'orig_text': [['If thou wilt leave me , do not leave me last ,']],
#     'pos_template': [['IN', 'JJ', 'NN', 'VBP', 'PRP', ',', 'VBP', 'RB', 'VB', 'PRP', 'JJ', ',']],
#     'repitition_template': [['0', '0', '0', '11', '21', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 202}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['happy', 'to'],
#     'orig_text': [['Happy to have thy love , happy to die !']],
#     'pos_template': [['JJ', 'TO', 'VB', 'JJ', 'NN', ',', 'JJ', 'TO', 'VB', '.']],
#     'repitition_template': [['11', '21', '0', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 203}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['the', 'summer'],
#     'orig_text': [["The summer's flower is to the summer sweet ,"]],
#     'pos_template': [['DT', 'NN', 'POS', 'NN', 'VBZ', 'TO', 'DT', 'NN', 'NN', ',']],
#     'repitition_template': [['11', '21', '0', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 205}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['the', 'time'],
#     'orig_text': [['Just to the time , not with the time exchanged ,']],
#     'pos_template': [['RB', 'TO', 'DT', 'NN', ',', 'RB', 'IN', 'DT', 'NN', 'VBD', ',']],
#     'repitition_template': [['0', '0', '11', '21', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 209}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 3,
#     'num_tokens': 12,
#     'num_tot_reps': 6,
#     'orig_rep_words': ['to', 'time', "'s"],
#     'orig_text': [["As subject to Time's love or to Time's hate ,"]],
#     'pos_template': [['IN', 'JJ', 'TO', 'NN', 'POS', 'NN', 'CC', 'TO', 'NN', 'POS', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '21', '31', '0', '0', '12', '22', '32', '0', '0']],
#     'unique_id': 211}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['thou', 'art'],
#     'orig_text': [['Thou art as tyrannous , so as thou art ,']],
#     'pos_template': [['JJ', 'NN', 'IN', 'JJ', ',', 'RB', 'IN', 'JJ', 'NN', ',']],
#     'repitition_template': [['11', '21', '0', '0', '0', '0', '0', '12', '22', '0']],
#     'unique_id': 216}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 14,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['and', 'will'],
#     'orig_text': [["And ' Will' to boot , and ' Will' in over-plus ;"]],
#     'pos_template': [['CC', "''", 'MD', "''", 'TO', 'VB', ',', 'CC', 'POS', 'MD', "''", 'IN', 'JJ', ':']],
#     'repitition_template': [['11', '0', '21', '0', '0', '0', '0', '12', '0', '22', '0', '0', '0', '0']],
#     'unique_id': 220}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 9,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['my', 'five'],
#     'orig_text': [['But my five wits nor my five senses can']],
#     'pos_template': [['CC', 'PRP$', 'CD', 'NNS', 'CC', 'PRP$', 'CD', 'NNS', 'MD']],
#     'repitition_template': [['0', '11', '21', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 224}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['thou', 'dost'],
#     'orig_text': [['If thou dost seek to have what thou dost hide ,']],
#     'pos_template': [['IN', 'JJ', 'NN', 'NN', 'TO', 'VB', 'WP', 'VBZ', 'NN', 'NN', ',']],
#     'repitition_template': [['0', '11', '21', '0', '0', '0', '0', '12', '22', '0', '0']],
#     'unique_id': 226}
#
#
# {   'fig_type': 'CONDUPLICATIO',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 14,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['how', 'can'],
#     'orig_text': [["How can it ? O ! how can Love's eye be true ,"]],
#     'pos_template': [['WRB', 'MD', 'PRP', '.', 'RB', '.', 'WRB', 'MD', 'VB', 'POS', 'NN', 'VB', 'JJ', ',']],
#     'repitition_template': [['11', '21', '0', '0', '0', '0', '12', '22', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 230}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['joy'],
#     'orig_text': [['Sweets with sweets war not , joy delights in joy :']],
#     'pos_template': [['NNS', 'IN', 'NNS', 'NN', 'RB', ',', 'NN', 'NNS', 'IN', 'NN', ':']],
#     'repitition_template': [['0', '0', '0', '0', '0', '0', '11', '0', '0', '12', '0']],
#     'unique_id': 233}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thought'],
#     'orig_text': [['But , ah ! thought kills me that I am not thought ,']],
#     'pos_template': [['CC', ',', 'RB', '.', 'NN', 'NNS', 'PRP', 'IN', 'NN', 'VBP', 'RB', 'VBN', ',']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 234}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 5,
#     'orig_rep_words': ['thou', 'art'],
#     'orig_text': [['Save where thou art not , though I feel thou art ,']],
#     'pos_template': [['VB', 'WRB', 'JJ', 'NN', 'RB', ',', 'IN', 'JJ', 'VBP', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '21', '0', '0', '12', '0', '0', '13', '22', '0']],
#     'unique_id': 235}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['earth'],
#     'orig_text': [['The earth can have but earth , which is his due ;']],
#     'pos_template': [['DT', 'NN', 'MD', 'VB', 'CC', 'NN', ',', 'WDT', 'VBZ', 'PRP$', 'JJ', ':']],
#     'repitition_template': [['0', '11', '0', '0', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 236}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['you'],
#     'orig_text': [['Than this rich praise , -- that you alone , are you ?']],
#     'pos_template': [['IN', 'DT', 'JJ', 'NN', ',', ':', 'IN', 'PRP', 'RB', ',', 'VBP', 'PRP', '.']],
#     'repitition_template': [['0', '0', '0', '0', '0', '0', '0', '11', '0', '0', '0', '12', '0']],
#     'unique_id': 237}
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['you'],
#     'orig_text': [['That you are you , so dignifies his story ,']],
#     'pos_template': [['IN', 'PRP', 'VBP', 'PRP', ',', 'IN', 'NNS', 'PRP$', 'NN', ',']],
#     'repitition_template': [['0', '11', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 238}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thy'],
#     'orig_text': [['If thy sweet virtue answer not thy show !']],
#     'pos_template': [['IN', 'JJ', 'JJ', 'NN', 'NN', 'RB', 'JJ', 'NN', '.']],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 239}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['best'],
#     'orig_text': [["But best is best , if never intermixed' ?"]],
#     'pos_template': [['CC', 'JJS', 'VBZ', 'RBS', ',', 'IN', 'RB', 'VBN', "''", '.']],
#     'repitition_template': [['0', '11', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 240}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['to', 'be'],
#     'orig_text': [['And to be praised of ages yet to be .']],
#     'pos_template': [['CC', 'TO', 'VB', 'VBN', 'IN', 'NNS', 'RB', 'TO', 'VB', '.']],
#     'repitition_template': [['0', '11', '21', '0', '0', '0', '0', '12', '22', '0']],
#     'unique_id': 241}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['kind'],
#     'orig_text': [['Kind is my love to-day , to-morrow kind ,']],
#     'pos_template': [['NN', 'VBZ', 'PRP$', 'NN', 'NN', ',', 'JJ', 'NN', ',']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 242}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['old'],
#     'orig_text': [['Counting no old thing old , thou mine , I thine ,']],
#     'pos_template': [['VBG', 'DT', 'JJ', 'NN', 'JJ', ',', 'JJ', 'NN', ',', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '0', '12', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 243}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 7,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['love'],
#     'orig_text': [['Admit impediments . Love is not love']],
#     'pos_template': [['NN', 'NNS', '.', 'NN', 'VBZ', 'RB', 'VB']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12']],
#     'unique_id': 244}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['better'],
#     'orig_text': [['That better is , by evil still made better ;']],
#     'pos_template': [['DT', 'JJR', 'VBZ', ',', 'IN', 'NN', 'RB', 'VBD', 'RBR', ':']],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 245}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 12,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['i', 'am'],
#     'orig_text': [['No , I am that I am , and they that level']],
#     'pos_template': [['DT', ',', 'VB', 'VBP', 'IN', 'NN', 'VBP', ',', 'CC', 'PRP', 'DT', 'NN']],
#     'repitition_template': [['0', '0', '11', '21', '0', '12', '22', '0', '0', '0', '0', '0']],
#     'unique_id': 246}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['weeds'],
#     'orig_text': [['Weeds among weeds , or flowers with flowers gathered .']],
#     'pos_template': [['NNS', 'IN', 'NNS', ',', 'CC', 'NNS', 'IN', 'NNS', 'VBN', '.']],
#     'repitition_template': [['11', '0', '12', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 247}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 10,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['thou', 'art'],
#     'orig_text': [['Thou art as tyrannous , so as thou art ,']],
#     'pos_template': [['JJ', 'NN', 'IN', 'JJ', ',', 'RB', 'IN', 'JJ', 'NN', ',']],
#     'repitition_template': [['11', '21', '0', '0', '0', '0', '0', '12', '22', '0']],
#     'unique_id': 248}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['see'],
#     'orig_text': [['That they behold , and see not what they see ?']],
#     'pos_template': [['IN', 'PRP', 'VBP', ',', 'CC', 'VB', 'RB', 'WP', 'PRP', 'VBP', '.']],
#     'repitition_template': [['0', '0', '0', '0', '0', '11', '0', '0', '0', '12', '0']],
#     'unique_id': 249}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['will'],
#     'orig_text': [["So will I pray that thou mayst have thy ' Will ,'"]],
#     'pos_template': [['RB', 'MD', 'VB', 'NN', 'IN', 'JJ', 'NNS', 'VBP', 'VBN', "''", 'MD', ',', "''"]],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 250}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 3,
#     'orig_rep_words': ['i'],
#     'orig_text': [['For I have sworn thee fair ; more perjured I ,']],
#     'pos_template': [['IN', 'NN', 'VBP', 'VBN', 'JJ', 'NN', ':', 'RBR', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '11', '0', '0', '0', '12', '0', '0', '0', '13', '0']],
#     'unique_id': 251}
#
#
# {   'fig_type': 'EPANALEPSIS',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['love'],
#     'orig_text': [["Love's fire heats water , water cools not love ."]],
#     'pos_template': [['NN', 'POS', 'NN', 'VBZ', 'NN', ',', 'NN', 'NNS', 'RB', 'VB', '.']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 252}
#
#
# {   'fig_type': 'EPISTROPHE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['hear'],
#     'orig_text': [["Music to hear , why hear ' st thou music sadly ?"]],
#     'pos_template': [['NN', 'TO', 'VB', ',', 'WRB', 'VBP', 'POS', 'JJ', 'NN', 'NN', 'RB', '.']],
#     'repitition_template': [['0', '0', '11', '0', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 254}
#
#
# {   'fig_type': 'EPISTROPHE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 14,
#     'num_tot_reps': 4,
#     'orig_rep_words': ['love', 'her'],
#     'orig_text': [["Thou dost love her , because thou know ' st I love her ;"]],
#     'pos_template': [['NN', 'NN', 'IN', 'PRP', ',', 'IN', 'NN', 'VBP', 'POS', 'NN', 'NN', 'VBP', 'PRP$', ':']],
#     'repitition_template': [['0', '0', '11', '21', '0', '0', '0', '0', '0', '0', '0', '12', '22', '0']],
#     'unique_id': 261}
#
#
# {   'fig_type': 'EPISTROPHE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['love'],
#     'orig_text': [['But love , for love , thus shall excuse my jade , --']],
#     'pos_template': [['CC', 'NN', ',', 'IN', 'NN', ',', 'RB', 'MD', 'VB', 'PRP$', 'NN', ',', ':']],
#     'repitition_template': [['0', '11', '0', '0', '12', '0', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 265}
#
#
# {   'fig_type': 'EPISTROPHE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 3,
#     'orig_rep_words': ['thou'],
#     'orig_text': [['So , love , be thou , although to-day thou fill']],
#     'pos_template': [['RB', ',', 'VB', ',', 'VB', 'VBN', ',', 'IN', 'JJ', 'NN', 'NN']],
#     'repitition_template': [['0', '0', '0', '0', '0', '11', '0', '12', '0', '13', '0']],
#     'unique_id': 267}
#
#
# {   'fig_type': 'EPISTROPHE',
#     'num_lines': 1,
#     'num_rep_groups': 2,
#     'num_tokens': 11,
#     'num_tot_reps': 5,
#     'orig_rep_words': ['i', 'found'],
#     'orig_text': [['I found , or thought I found , you did exceed']],
#     'pos_template': [['NN', 'VBD', ',', 'CC', 'VBD', 'NN', 'VBD', ',', 'PRP', 'VBD', 'VB']],
#     'repitition_template': [['11', '21', '0', '0', '0', '12', '22', '0', '0', '13', '0']],
#     'unique_id': 270}
#
#
# {   'fig_type': 'EPISTROPHE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['woe'],
#     'orig_text': [['And other strains of woe , which now seem woe ,']],
#     'pos_template': [['CC', 'JJ', 'NNS', 'IN', 'NN', ',', 'WDT', 'RB', 'VBP', 'NNS', ',']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 273}
#
#
# {   'fig_type': 'EPISTROPHE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['less'],
#     'orig_text': [['I love not less , though less the show appear ;']],
#     'pos_template': [['NNS', 'VBP', 'RB', 'RBR', ',', 'RB', 'JJR', 'DT', 'NN', 'VBP', ':']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 276}
#
#
# ...
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['fears'],
#     'orig_text': [['Applying fears to hopes , and hopes to fears ,']],
#     'pos_template': [['VBG', 'NNS', 'TO', 'NNS', ',', 'CC', 'VBZ', 'TO', 'NNS', ',']],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 543}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['hopes'],
#     'orig_text': [['Applying fears to hopes , and hopes to fears ,']],
#     'pos_template': [['VBG', 'NNS', 'TO', 'NNS', ',', 'CC', 'VBZ', 'TO', 'NNS', ',']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '0']],
#     'unique_id': 544}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['better'],
#     'orig_text': [['That better is , by evil still made better ;']],
#     'pos_template': [['DT', 'JJR', 'VBZ', ',', 'IN', 'NN', 'RB', 'VBD', 'RBR', ':']],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 546}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['vile'],
#     'orig_text': [["' Tis better to be vile than vile esteemed ,"]],
#     'pos_template': [['POS', 'NN', 'RBR', 'TO', 'VB', 'JJ', 'IN', 'NN', 'VBN', ',']],
#     'repitition_template': [['0', '0', '0', '0', '0', '11', '0', '12', '0', '0']],
#     'unique_id': 547}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thy'],
#     'orig_text': [['Thy gift , thy tables , are within my brain']],
#     'pos_template': [['JJ', 'NN', ',', 'JJ', 'NNS', ',', 'VBP', 'IN', 'PRP$', 'NN']],
#     'repitition_template': [['11', '0', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 549}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['nothing'],
#     'orig_text': [['To me are nothing novel , nothing strange ;']],
#     'pos_template': [['TO', 'PRP', 'VBP', 'NN', 'NN', ',', 'NN', 'NN', ':']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0']],
#     'unique_id': 551}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['time'],
#     'orig_text': [["As subject to Time's love or to Time's hate ,"]],
#     'pos_template': [['IN', 'JJ', 'TO', 'NN', 'POS', 'NN', 'CC', 'TO', 'NN', 'POS', 'NN', ',']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '0', '0', '12', '0', '0', '0']],
#     'unique_id': 552}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['weeds'],
#     'orig_text': [['Weeds among weeds , or flowers with flowers gathered .']],
#     'pos_template': [['NNS', 'IN', 'NNS', ',', 'CC', 'NNS', 'IN', 'NNS', 'VBN', '.']],
#     'repitition_template': [['11', '0', '12', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 553}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['flowers'],
#     'orig_text': [['Weeds among weeds , or flowers with flowers gathered .']],
#     'pos_template': [['NNS', 'IN', 'NNS', ',', 'CC', 'NNS', 'IN', 'NNS', 'VBN', '.']],
#     'repitition_template': [['0', '0', '0', '0', '0', '11', '0', '12', '0', '0']],
#     'unique_id': 554}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['fickle'],
#     'orig_text': [["Dost hold Time's fickle glass , his fickle hour ;"]],
#     'pos_template': [['NN', 'VBP', 'NN', 'POS', 'JJ', 'NN', ',', 'PRP$', 'JJ', 'NN', ':']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 556}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thy'],
#     'orig_text': [["Thy lovers withering , as thy sweet self grow ' st."]],
#     'pos_template': [['JJ', 'NNS', 'VBG', ',', 'IN', 'JJ', 'JJ', 'NN', 'NN', 'POS', 'NN', '.']],
#     'repitition_template': [['11', '0', '0', '0', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 557}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['music'],
#     'orig_text': [["How oft when thou , my music , music play ' st ,"]],
#     'pos_template': [['WRB', 'JJ', 'WRB', 'NN', ',', 'PRP$', 'NN', ',', 'NN', 'NN', "''", 'NN', ',']],
#     'repitition_template': [['0', '0', '0', '0', '0', '0', '11', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 561}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thy'],
#     'orig_text': [['Give them thy fingers , me thy lips to kiss .']],
#     'pos_template': [['VB', 'PRP', 'JJ', 'NNS', ',', 'PRP', 'JJ', 'NNS', 'TO', 'VB', '.']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 562}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['lust'],
#     'orig_text': [['Is lust in action : and till action , lust']],
#     'pos_template': [['VBZ', 'JJ', 'IN', 'NN', ':', 'CC', 'VB', 'NN', ',', 'NN']],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '0', '0', '12']],
#     'unique_id': 563}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['action'],
#     'orig_text': [['Is lust in action : and till action , lust']],
#     'pos_template': [['VBZ', 'JJ', 'IN', 'NN', ':', 'CC', 'VB', 'NN', ',', 'NN']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 564}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['well'],
#     'orig_text': [['All this the world well knows ; yet none knows well']],
#     'pos_template': [['DT', 'DT', 'DT', 'NN', 'NN', 'VBZ', ':', 'RB', 'NN', 'VBZ', 'RB']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '0', '0', '0', '12']],
#     'unique_id': 569}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['knows'],
#     'orig_text': [['All this the world well knows ; yet none knows well']],
#     'pos_template': [['DT', 'DT', 'DT', 'NN', 'NN', 'VBZ', ':', 'RB', 'NN', 'VBZ', 'RB']],
#     'repitition_template': [['0', '0', '0', '0', '0', '11', '0', '0', '0', '12', '0']],
#     'unique_id': 570}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['red'],
#     'orig_text': [['Coral is far more red , than her lips red :']],
#     'pos_template': [['NN', 'VBZ', 'RB', 'RBR', 'JJ', ',', 'IN', 'PRP$', 'NNS', 'JJ', ':']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 571}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['wires'],
#     'orig_text': [['If hairs be wires , black wires grow on her head .']],
#     'pos_template': [['IN', 'NNS', 'VB', 'NNS', ',', 'JJ', 'NNS', 'VBP', 'IN', 'PRP$', 'NN', '.']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '0', '0', '0']],
#     'unique_id': 572}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['art'],
#     'orig_text': [['Thou art as tyrannous , so as thou art ,']],
#     'pos_template': [['JJ', 'NN', 'IN', 'JJ', ',', 'RB', 'IN', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 574}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['heart'],
#     'orig_text': [['Beshrew that heart that makes my heart to groan']],
#     'pos_template': [['NN', 'WDT', 'NN', 'WDT', 'VBZ', 'PRP$', 'NN', 'TO', 'VB']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 577}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 10,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['hold'],
#     'orig_text': [['For nothing hold me , so it please thee hold']],
#     'pos_template': [['IN', 'NN', 'NN', 'PRP', ',', 'IN', 'PRP', 'VB', 'JJ', 'NN']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '0', '0', '0', '12']],
#     'unique_id': 591}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['power'],
#     'orig_text': [['Use power with power , and slay me not by art ,']],
#     'pos_template': [['NN', 'NN', 'IN', 'NN', ',', 'CC', 'VB', 'PRP', 'RB', 'IN', 'NN', ',']],
#     'repitition_template': [['0', '11', '0', '12', '0', '0', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 600}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['words'],
#     'orig_text': [['Lest sorrow lend me words , and words express']],
#     'pos_template': [['JJS', 'NN', 'VB', 'PRP', 'NNS', ',', 'CC', 'NNS', 'NN']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '12', '0']],
#     'unique_id': 601}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 14,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['love'],
#     'orig_text': [['Though not to love , yet , love to tell me so ; --']],
#     'pos_template': [['IN', 'RB', 'TO', 'VB', ',', 'RB', ',', 'VB', 'TO', 'VB', 'PRP', 'RB', ':', ':']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 602}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 8,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['mad'],
#     'orig_text': [['Mad slanderers by mad ears believed be .']],
#     'pos_template': [['JJ', 'NNS', 'IN', 'JJ', 'NNS', 'VBD', 'VB', '.']],
#     'repitition_template': [['11', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 603}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 9,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['five'],
#     'orig_text': [['But my five wits nor my five senses can']],
#     'pos_template': [['CC', 'PRP$', 'CD', 'NNS', 'CC', 'PRP$', 'CD', 'NNS', 'MD']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 606}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['dost'],
#     'orig_text': [['If thou dost seek to have what thou dost hide ,']],
#     'pos_template': [['IN', 'JJ', 'NN', 'NN', 'TO', 'VB', 'WP', 'VBZ', 'NN', 'NN', ',']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 614}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['will'],
#     'orig_text': [["So will I pray that thou mayst have thy ' Will ,'"]],
#     'pos_template': [['RB', 'MD', 'VB', 'NN', 'IN', 'JJ', 'NNS', 'VBP', 'VBN', "''", 'MD', ',', "''"]],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 616}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['hate'],
#     'orig_text': [["' I hate' , from hate away she threw ,"]],
#     'pos_template': [['POS', 'JJ', 'NN', "''", ',', 'IN', 'NN', 'RB', 'PRP', 'VBD', ',']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 619}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['past'],
#     'orig_text': [['Past cure I am , now Reason is past care ,']],
#     'pos_template': [['JJ', 'NN', 'NN', 'VBP', ',', 'RB', 'NN', 'VBZ', 'JJ', 'NN', ',']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 623}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 12,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thee'],
#     'orig_text': [['For I have sworn thee fair , and thought thee bright ,']],
#     'pos_template': [['IN', 'NN', 'VBP', 'VBN', 'JJ', 'NN', ',', 'CC', 'VBD', 'NNS', 'JJ', ',']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 624}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 14,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['can'],
#     'orig_text': [["How can it ? O ! how can Love's eye be true ,"]],
#     'pos_template': [['WRB', 'MD', 'PRP', '.', 'RB', '.', 'WRB', 'MD', 'VB', 'POS', 'NN', 'VB', 'JJ', ',']],
#     'repitition_template': [['0', '11', '0', '0', '0', '0', '0', '12', '0', '0', '0', '0', '0', '0']],
#     'unique_id': 628}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['thee'],
#     'orig_text': [['Who taught thee how to make me love thee more ,']],
#     'pos_template': [['WP', 'VBD', 'VB', 'WRB', 'TO', 'VB', 'PRP', 'VB', 'RB', 'RBR', ',']],
#     'repitition_template': [['0', '0', '11', '0', '0', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 632}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['deep'],
#     'orig_text': [['For I have sworn deep oaths of thy deep kindness ,']],
#     'pos_template': [['IN', 'NN', 'VBP', 'VBN', 'JJ', 'NNS', 'IN', 'JJ', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '0', '0', '12', '0', '0']],
#     'unique_id': 640}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['love'],
#     'orig_text': [["Love's fire heats water , water cools not love ."]],
#     'pos_template': [['NN', 'POS', 'NN', 'VBZ', 'NN', ',', 'NN', 'NNS', 'RB', 'VB', '.']],
#     'repitition_template': [['11', '0', '0', '0', '0', '0', '0', '0', '0', '12', '0']],
#     'unique_id': 642}
#
#
# {   'fig_type': 'PLOCE',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 11,
#     'num_tot_reps': 2,
#     'orig_rep_words': ['water'],
#     'orig_text': [["Love's fire heats water , water cools not love ."]],
#     'pos_template': [['NN', 'POS', 'NN', 'VBZ', 'NN', ',', 'NN', 'NNS', 'RB', 'VB', '.']],
#     'repitition_template': [['0', '0', '0', '0', '11', '0', '12', '0', '0', '0', '0']],
#     'unique_id': 643}
#
#
# {   'fig_type': 'POLYSYNDETON',
#     'num_lines': 1,
#     'num_rep_groups': 1,
#     'num_tokens': 13,
#     'num_tot_reps': 3,
#     'orig_rep_words': ['nor'],
#     'orig_text': [['Since brass , nor stone , nor earth , nor boundless sea ,']],
#     'pos_template': [['IN', 'NN', ',', 'CC', 'NN', ',', 'CC', 'NN', ',', 'CC', 'JJ', 'NN', ',']],
#     'repitition_template': [['0', '0', '0', '11', '0', '0', '12', '0', '0', '13', '0', '0', '0']],
#     'unique_id': 664}

# %%
scoring_table = {
    RHETORICAL_FIGURES.ANADIPLOSIS: list(np.logspace(1, .1, 10, endpoint=True)),
    RHETORICAL_FIGURES.ANAPHORA: list(np.logspace(1, .1, 10, endpoint=True)), 
    RHETORICAL_FIGURES.ANTIMETABOLE: list(np.logspace(1, .1, 10, endpoint=True)), 
    RHETORICAL_FIGURES.CONDUPLICATIO: list(np.logspace(1, .1, 10, endpoint=True)), 
    RHETORICAL_FIGURES.EPANALEPSIS: list(np.logspace(1, .1, 10, endpoint=True)), 
    RHETORICAL_FIGURES.EPISTROPHE: list(np.logspace(1, .1, 10, endpoint=True)), 
    RHETORICAL_FIGURES.EPIZEUXIS: list(np.logspace(1, .1, 10, endpoint=True)), 
    RHETORICAL_FIGURES.PLOCE: list(np.logspace(1, .1, 10, endpoint=True)), 
    RHETORICAL_FIGURES.POLYSYNDETON: list(np.logspace(1, .1, 10, endpoint=True)), 
    RHETORICAL_FIGURES.SYMPLOCE: list(np.logspace(1, .1, 10, endpoint=True))         
} 
print(scoring_table)
print(scoring_table[RHETORICAL_FIGURES.ANADIPLOSIS])
# Out:
# {<RHETORICAL_FIGURES.ANADIPLOSIS: 0>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.ANAPHORA: 1>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.ANTIMETABOLE: 2>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.CONDUPLICATIO: 3>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.EPANALEPSIS: 4>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.EPISTROPHE: 5>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.EPIZEUXIS: 6>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.PLOCE: 7>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.POLYSYNDETON: 8>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673], <RHETORICAL_FIGURES.SYMPLOCE: 9>: [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673]}
# [10.0, 7.943282347242816, 6.309573444801933, 5.011872336272722, 3.9810717055349722, 3.1622776601683795, 2.5118864315095797, 1.9952623149688793, 1.5848931924611134, 1.2589254117941673]
