# %%
import py_files.Rhetoric as Rhetoric
import argparse
import os
import pprint
import nltk
import numpy as np
import time
import pandas as pd
from datetime import datetime

def uniq(input):
  output = []
  for x in input:
    if x not in output:
      output.append(x)
  return output

def recursive_len(item):
    if type(item) == list:
        return sum(recursive_len(subitem) for subitem in item)
    else:
        return 1


#os.getcwd()
#parser = argparse.ArgumentParser(description='Do rhetorical analysis')

#parser.add_argument('input', help='''Input file name (located in data/) e.g. sonnets.txt''')


#args = parser.parse_args()
args = dict()
args["input"] = "sonnets.txt"
local_path_input = 'data/' + args["input"]
abs_path_input = os.path.abspath(local_path_input)
filename, file_extension = os.path.splitext(abs_path_input)
corpus, extension = os.path.splitext(args["input"])

corpus_input = 'data/rhet/' + corpus + '_input_corpus' + '.txt'
sent_table = pd.read_csv(corpus_input, delimiter='|', usecols=['text'])
#print(sent_table)


for i in sent_table.index.values:
    #print(sent_table.iloc[i]['text']);
    #sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace('''O ''', '''Oh''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace('''`''', ''' \'''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace(''' ` ''', '''\'''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace(''' `''', '''\'''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace(''' \'''','''\'''')
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].replace('''\'d''','''ed''')
    #sent_table.iloc[i]['text'] = re.sub(r'''[^\w\d'\-\s]+''','',sent_table.iloc[i]['text']);
    sent_table.iloc[i]['text'] = sent_table.iloc[i]['text'].strip();

pwd_dir = "/home/dineshp/Poetix18/"
output_folder_rep = "%s/data/rhet/repitition" % (pwd_dir)

unique_id = 0
fig_dict = dict()

for e,d in zip(Rhetoric.RHETORICAL_FIGURES, Rhetoric.FIGURE_DESCRIPTION):

    cur_fig_name = e.name
    cur_fig_desc = d.value
    cur_fig_rhet_file = '''%s/%s_%s.csv''' % (output_folder_rep, corpus, e.name.lower())
    print(cur_fig_desc)
    print(cur_fig_rhet_file)

    rhet_table = pd.read_csv(cur_fig_rhet_file)
    # print(rhet_table)
    fig_ids = rhet_table.figure_id.unique()
    # print(fig_ids)
    for id in fig_ids:
        figure = rhet_table.loc[rhet_table['figure_id'] == id]
        rep_word = []
        sentence_ids = figure['sentence_id'].values
        sentence_ids = uniq(sentence_ids)
        if (not sorted(sentence_ids) == list(range(min(sentence_ids), max(sentence_ids) + 1))): continue

        fig_words = uniq([x.lower().replace('''\'d''', '''ed''') for x in list(figure['word'].values)])
        fig_words_dict = dict([[fig_words[y - 1], y] for y in range(1, len(fig_words) + 1)])
        # print(fig_words_dict)

        orig_text = [nltk.word_tokenize(sent_table.iloc[i]['text']) for i in sentence_ids]

        # for l in range(0,len(roman)):
        # del orig_text[roman[l][0]][roman[l][1]]

        orig_text = [[orig_text[i][j].lower() for j in range(0, len(orig_text[i]))] for i in range(0, len(orig_text))]
        if (recursive_len(orig_text) > 1):
            tagged = [nltk.pos_tag(orig_text[i]) for i in range(0, len(orig_text))]
            # print(orig_text)
            pos_templates = [[tagged[i][j][1] for j in range(0, len(tagged[i]))] for i in range(0, len(tagged))]
            
            # print(pos_templates)

            assert (np.shape(orig_text) == np.shape(pos_templates))
            fig_words_count_dict = dict([[fig_words[y], 0] for y in range(0, len(fig_words))])

            rep_templates = [['0' for j in range(0, len(orig_text[i]))] for i in range(0, len(orig_text))]
            for j in range(0, len(orig_text)):
                for k in range(0, len(orig_text[j])):
                    wordc = orig_text[j][k]
                    for word_rep in list(fig_words_dict.keys()):
                        if (word_rep in wordc):
                            fig_words_count_dict[word_rep] = fig_words_count_dict[word_rep] + 1
                            rep_templates[j][k] = str(fig_words_dict[word_rep]) + str(fig_words_count_dict[word_rep])

            unique_id = unique_id + 1
            #print("unique_id: " + str(unique_id))
            #print("num_lines: " + str(len(sentence_ids)))
            #print("num_tokens: " + str(recursive_len(orig_text)))
            #print("num_rep_groups: " + str(len(fig_words_dict.keys())))
            #print("num_tot_reps: " + str(sum(fig_words_count_dict.values())))
            #print("fig_type: " + str(cur_fig_name)+ "\n")
            #print("Orig. Text:\n")
            orig_line = ", ".join([' '.join(orig_text[i]) for i in range(0, len(orig_text))])
            fig_info = Rhetoric.FigureInfo(unique_id, [[sent_table.iloc[i]['text']] for i in sentence_ids], pos_templates,
                                  rep_templates)
            fig_info.set_props(len(sentence_ids), recursive_len(orig_text), len(fig_words_dict.keys()),
                               sum(fig_words_count_dict.values()), e.name)
            fig_info.set_orig_rep_words([k for k in fig_words_dict.keys()])
            fig_info.set_orig_tokens(orig_text)
            fig_dict[unique_id] = fig_info
            #print(orig_text)
            #print(rep_templates)
            #print(pos_templates)
            #print("Rep. Words:\n")
            #print(fig_words_dict)
            #print("Rep. Words Count:\n")
            #print(fig_words_count_dict)
            #print("POS Template:\n")
            #print(pos_templates)
            #print("Rep Template:\n")
            #print(rep_templates)

# for index, row in figure.iterrows():

#print(fig_dict.values)
# Out:
# Repetition of the ending word or phrase from the previous clause at the beginning of the next.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_anadiplosis.csv
# Repetition of a word or phrase at the beginning of successive phrases or clauses.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_anaphora.csv
# Repetition of words in reverse grammatical order.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_antimetabole.csv
# The repetition of a word or phrase.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_conduplicatio.csv
# Repetition at the end of a clause of the word or phrase that began it.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_epanalepsis.csv
# Repetition of the same word or phrase at the end of successive clauses.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_epistrophe.csv
# Repetition of a word or phrase with no others between.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_epizeuxis.csv
# The repetition of word in a short span of text for rhetorical emphasis.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_ploce.csv
# "Excessive" repetition of conjunctions between clauses.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_polysyndeton.csv
# Repetition of a word or phrase at the beginning, and of another at the end, of successive clauses.
# /home/dineshp/Poetix18//data/rhet/repitition/sonnets_symploce.csv

# %%
from py_files.Limericks import Limerick_Generate

timestamp = int(time.mktime(datetime.now().timetuple()))
lg = Limerick_Generate(model_dir='gpt2/models/345M',model_name='345M')
n = 10
top_sent = 5

for e,d in zip(Rhetoric.RHETORICAL_FIGURES, Rhetoric.FIGURE_DESCRIPTION):

    #out_name = 'data/rhet/output/' + corpus + "_" + e.name.lower() + "_" + str(timestamp)  + ".txt"
    #f = open(out_name,"w+")

    fig_and_desc = e.name + ": " + d.value
    #f.write("FIGURE: Description\n")
    #f.write(fig_and_desc +" \n\n")

    #print(out_name)
    #print(fig_and_desc)
    filtered = {k: v for k, v in fig_dict.items() if(v.get_num_lines() == 2 and v.get_fig_type() == e.name)}
    #print(len(filtered))   


    for k, v in filtered.items():
       #print(fig_and_desc)
       gen_lines = lg.gen_line_gpt_rep_multiline(v, search_space=n, top_sent=top_sent)
       v.set_gen_lines(gen_lines)
       print(v.to_string())
# Out:
# ['state']
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/dineshp/Poetix18/gpt2/src/score.py:55: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where'], ['when'], ['how'], ['why'], ['whenever'], ['how'], ['where'], ['when'], ['wherever'], ['when']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where government'], ['how soever'], ['why cannot'], ['how soever'], ['where justice'], ['how cannot'], ['where man'], ['where money'], ['where power'], ['where authority']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where government cannot'], ['where money cannot'], ['where justice cannot'], ['how soever remote'], ['how soever remote'], ['where government are'], ['where man cannot'], ['where government have'], ['how soever imperfect'], ['where authority cannot']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where government have been'], ['where money cannot come'], ['where government have made'], ['where government have given'], ['where government cannot come'], ['where government have taken'], ['where government have done'], ['where justice cannot come'], ['where government are divided'], ['where government cannot put']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where government have been able'], ['where government have taken such'], ['where government have made such'], ['where government have done much'], ['where government have done such'], ['where government have been entrusted'], ['where government have been unable'], ['where government have done many'], ['where government have made many'], ['where government have done good']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where government have taken such action'], ['where government have done such thing'], ['where government have done good work'], ['where government have done much harm'], ['where government have taken such care'], ['where government have done such work'], ['where government have done good thing'], ['where government have done much work'], ['where government have taken such step'], ['where government have done such mischief']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where government have done such thing as'], ['where government have taken such action as'], ['where government have taken such care of'], ['where government have done good work for'], ['where government have done good work in'], ['where government have done much work for'], ['where government have done such work for'], ['where government have taken such action against'], ['where government have taken such care in'], ['where government have done such work as']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where government have taken such care of business'], ['where government have done good work for society'], ['where government have done good work for mankind'], ['where government have done good work in relation'], ['where government have done good work for man'], ['where government have done good work in regard'], ['where government have done good work in respect'], ['where government have done much work for society'], ['where government have taken such care of property'], ['where government have done good work in order']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['where government have taken such care of business ,'], ['where government have done good work for society ,'], ['where government have done good work for mankind ,'], ['where government have taken such care of business ,'], ['where government have done good work for man ,'], ['where government have done good work for society ,'], ['where government have done much work for society ,'], ['where government have done good work for mankind ,'], ['where government have taken such care of property ,'], ['where government have done good work for man ,']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and'], ['but'], ['or'], ['nor'], ['and'], ['but'], ['or'], ['and'], ['or'], ['nor']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and business'], ['or business'], ['but business'], ['nor business'], ['and business'], ['but business'], ['and business'], ['or business'], ['but business'], ['or business']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or business itself'], ['and business itself'], ['nor business itself'], ['but business itself'], ['or business himself'], ['or business itself'], ['or business it'], ['and business it'], ['or business themselves'], ['and business itself']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or business itself made'], ['or business itself lost'], ['but business itself was'], ['and business itself was'], ['or business itself was'], ['or business itself corrupted'], ['or business itself put'], ['or business itself turned'], ['or business itself brought'], ['or business itself deceived']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or business itself corrupted ,'], ['or business itself lost ,'], ['or business itself deceived ,'], ['or business itself lost ,'], ['or business itself corrupted ,'], ['or business itself deceived ,'], ['or business itself turned ,'], ['or business itself made ,'], ['but business itself was ,'], ['and business itself was ,']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or business itself corrupted , to'], ['or business itself deceived , to'], ['or business itself lost , to'], ['or business itself lost , to'], ['or business itself corrupted , to'], ['or business itself deceived , to'], ['or business itself turned , to'], ['or business itself made , to'], ['and business itself was , to'], ['but business itself was , to']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or business itself corrupted , to be'], ['or business itself deceived , to be'], ['or business itself lost , to be'], ['or business itself corrupted , to become'], ['or business itself deceived , to lose'], ['or business itself corrupted , to decay'], ['or business itself corrupted , to lose'], ['or business itself corrupted , to fall'], ['or business itself lost , to lose'], ['or business itself deceived , to fall']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or business itself corrupted , to be ;'], ['or business itself deceived , to be ;'], ['or business itself lost , to be ;'], ['or business itself corrupted , to become ;'], ['or business itself deceived , to lose ;'], ['or business itself corrupted , to decay ;'], ['or business itself corrupted , to lose ;'], ['or business itself corrupted , to fall ;'], ['or business itself lost , to lose ;'], ['or business itself deceived , to fall ;']]
# {'sents': [['or', 'business', 'itself', 'corrupted', ',', 'to', 'be', ';']], 'used_words_dict': {}}
# [['where government have taken such care of business ,', ['or', 'business', 'itself', 'corrupted', ',', 'to', 'be', ';']], ['where government have done good work for society ,'], ['where government have done good work for mankind ,'], ['where government have taken such care of business ,'], ['where government have done good work for man ,']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and'], ['but'], ['or'], ['nor'], ['and'], ['but'], ['or'], ['and'], ['or'], ['nor']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and society'], ['but society'], ['or society'], ['and society'], ['and society'], ['but society'], ['but society'], ['nor society'], ['or society'], ['or society']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and society itself'], ['or society itself'], ['but society itself'], ['and society it'], ['and society itself'], ['and society we'], ['and society he'], ['and society i'], ['and society itself'], ['and society himself']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['but society itself was'], ['and society itself was'], ['and society itself became'], ['and society itself lost'], ['and society itself made'], ['and society itself fell'], ['or society itself made'], ['or society itself lost'], ['or society itself corrupted'], ['and society itself corrupted']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or society itself corrupted ,'], ['and society itself corrupted ,'], ['or society itself lost ,'], ['and society itself fell ,'], ['and society itself corrupted ,'], ['or society itself corrupted ,'], ['and society itself was ,'], ['but society itself was ,'], ['and society itself lost ,'], ['or society itself lost ,']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or society itself corrupted , to'], ['and society itself corrupted , to'], ['or society itself lost , to'], ['or society itself corrupted , to'], ['and society itself corrupted , to'], ['or society itself lost , to'], ['and society itself fell , to'], ['and society itself lost , to'], ['and society itself was , to'], ['but society itself was , to']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or society itself corrupted , to be'], ['or society itself corrupted , to decay'], ['or society itself corrupted , to become'], ['or society itself corrupted , to fall'], ['and society itself corrupted , to become'], ['and society itself corrupted , to decay'], ['and society itself corrupted , to be'], ['or society itself corrupted , to lose'], ['or society itself lost , to decay'], ['or society itself lost , to be']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or society itself corrupted , to be ;'], ['or society itself corrupted , to decay ;'], ['or society itself corrupted , to become ;'], ['or society itself corrupted , to fall ;'], ['and society itself corrupted , to become ;'], ['and society itself corrupted , to decay ;'], ['and society itself corrupted , to be ;'], ['or society itself corrupted , to lose ;'], ['or society itself lost , to decay ;'], ['or society itself lost , to be ;']]
# {'sents': [['or', 'society', 'itself', 'corrupted', ',', 'to', 'be', ';']], 'used_words_dict': {}}
# [['where government have taken such care of business ,', ['or', 'business', 'itself', 'corrupted', ',', 'to', 'be', ';']], ['where government have done good work for society ,', ['or', 'society', 'itself', 'corrupted', ',', 'to', 'be', ';']], ['where government have done good work for mankind ,'], ['where government have taken such care of business ,'], ['where government have done good work for man ,']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and'], ['but'], ['or'], ['nor'], ['and'], ['but'], ['or'], ['and'], ['or'], ['nor']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and mankind'], ['but mankind'], ['or mankind'], ['but mankind'], ['and mankind'], ['and mankind'], ['but mankind'], ['nor mankind'], ['or mankind'], ['or mankind']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and mankind itself'], ['but mankind itself'], ['or mankind itself'], ['and mankind himself'], ['and mankind he'], ['and mankind it'], ['but mankind himself'], ['and mankind themselves'], ['but mankind he'], ['but mankind i']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and mankind itself was'], ['but mankind itself was'], ['and mankind it was'], ['and mankind itself became'], ['and mankind himself was'], ['and mankind itself lost'], ['and mankind itself had'], ['but mankind itself had'], ['and mankind itself fell'], ['but mankind himself was']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and mankind it was ,'], ['and mankind itself fell ,'], ['and mankind itself was ,'], ['and mankind it was ,'], ['but mankind itself was ,'], ['and mankind itself lost ,'], ['and mankind itself lost ,'], ['and mankind itself became ,'], ['and mankind himself was ,'], ['and mankind itself had ,']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and mankind it was , to'], ['and mankind it was , to'], ['and mankind itself lost , to'], ['and mankind itself fell , to'], ['and mankind itself lost , to'], ['and mankind itself was , to'], ['but mankind itself was , to'], ['and mankind itself became , to'], ['and mankind himself was , to'], ['and mankind itself had , to']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and mankind it was , to be'], ['and mankind itself fell , to decay'], ['and mankind it was , to be'], ['and mankind it was , to fall'], ['and mankind it was , to become'], ['and mankind itself lost , to decay'], ['and mankind itself lost , to be'], ['and mankind it was , to decay'], ['and mankind it was , to destroy'], ['and mankind it was , to perish']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and mankind it was , to be ;'], ['and mankind itself fell , to decay ;'], ['and mankind it was , to be ;'], ['and mankind it was , to fall ;'], ['and mankind it was , to become ;'], ['and mankind itself lost , to decay ;'], ['and mankind itself lost , to be ;'], ['and mankind it was , to decay ;'], ['and mankind it was , to destroy ;'], ['and mankind it was , to perish ;']]
# {'sents': [['and', 'mankind', 'it', 'was', ',', 'to', 'be', ';']], 'used_words_dict': {}}
# [['where government have taken such care of business ,', ['or', 'business', 'itself', 'corrupted', ',', 'to', 'be', ';']], ['where government have done good work for society ,', ['or', 'society', 'itself', 'corrupted', ',', 'to', 'be', ';']], ['where government have done good work for mankind ,', ['and', 'mankind', 'it', 'was', ',', 'to', 'be', ';']], ['where government have taken such care of business ,'], ['where government have done good work for man ,']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and'], ['but'], ['or'], ['nor'], ['and'], ['but'], ['or'], ['and'], ['or'], ['nor']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['and business'], ['or business'], ['but business'], ['nor business'], ['and business'], ['but business'], ['and business'], ['or business'], ['but business'], ['or business']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or business itself'], ['and business itself'], ['nor business itself'], ['but business itself'], ['or business himself'], ['or business itself'], ['or business it'], ['and business it'], ['or business themselves'], ['and business itself']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
# [['or business itself made'], ['or business itself lost'], ['but business itself was'], ['and business itself was'], ['or business itself was'], ['or business itself corrupted'], ['or business itself put'], ['or business itself turned'], ['or business itself brought'], ['or business itself deceived']]
# INFO:tensorflow:Restoring parameters from gpt2/models/345M/model.ckpt
